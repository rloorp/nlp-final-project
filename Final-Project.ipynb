# %%
import pandas as pd
from google.colab import drive
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import numpy as np
import torch
from transformers import DistilBertTokenizer, DistilBertModel
import time
from sklearn.cluster import KMeans
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
import math

# %%
#Cargar desde Google drive

drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/NLP/enron_clean.csv'
df = pd.read_csv(file_path)

#Mostrar head
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Unnamed: 0                       date                   sender  \
# 0           0  2001-05-14 16:39:00-07:00  phillip.allen@enron.com
# 1           1  2001-05-04 13:51:00-07:00  phillip.allen@enron.com
# 2           2  2000-10-18 03:00:00-07:00  phillip.allen@enron.com
# 3           3  2000-10-23 06:13:00-07:00  phillip.allen@enron.com
# 4           4  2000-08-31 05:07:00-07:00  phillip.allen@enron.com
#
#                 recipient1    subject  \
# 0     tim.belden@enron.com        NaN
# 1  john.lavorato@enron.com        Re:
# 2   leah.arsdall@enron.com   Re: test
# 3    randall.gay@enron.com        NaN
# 4     greg.piper@enron.com  Re: Hello
#
#                                                 text
# 0              ['', 'Here is our forecast', '', ' ']
# 1  ['', 'Traveling to have a business meeting tak...
# 2             ['', 'test successful.  way to go!!!']
# 3  ['', 'Randy,', '', ' Can you send me a schedul...
# 4        ['', "Let's shoot for Tuesday at 11:45.  "]

# %%
# Eliminar comillas y listas del campo 'text'
def clean_text(text):
    text = re.sub(r'\[\'|\'\]', '', text)
    text = re.sub(r'[\'\"]', '', text)
    text = text.strip()
    return text

df['clean_text'] = df['text'].apply(clean_text)

# Filtrar correos vacíos o demasiado cortos
df_filtered = df[df['clean_text'].str.len() > 30]

# %%
# Lista de frases comunes para eliminar
phrases_to_remove = ['Thank you', 'Best regards', 'Please cc', 'Sincerely', 'Re:']

def remove_signatures(text):
    for phrase in phrases_to_remove:
        text = text.replace(phrase, '')
    return text.strip()

df_filtered['clean_text'] = df_filtered['clean_text'].apply(remove_signatures)
# Out:
# <ipython-input-60-74d0151c6f9c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['clean_text'] = df_filtered['clean_text'].apply(remove_signatures)

# %%
# Descargar punkt: tokenizer y stopwords
nltk.download('punkt')
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

def tokenize_and_remove_stopwords(text):
    tokens = word_tokenize(text)
    filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
    return ' '.join(filtered_tokens)

df_filtered['clean_text'] = df_filtered['clean_text'].apply(tokenize_and_remove_stopwords)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-61-31732fe7be9c>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['clean_text'] = df_filtered['clean_text'].apply(tokenize_and_remove_stopwords)

# %%
# Vectorizar
vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
text_vectorized = vectorizer.fit_transform(df_filtered['clean_text'])

#LDA
lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(text_vectorized)

for index, topic in enumerate(lda.components_):
    print(f'Tema {index}:')
    print([vectorizer.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
# Out:
# Tema 0:
# ['information', 'time', 'california', 'gas', 'enron', '2001', 'energy', 'market', 'power', '00']
# Tema 1:
# ['tr', 'size', 'br', 'image', 'www', 'com', 'td', 'font', 'http', '09']
# Tema 2:
# ['jeff', 'pm', 'original', 'sent', 'subject', 'message', 'enron', '2001', 'mail', 'com']
# Tema 3:
# ['company', 'www', 'http', 'new', 'million', 'said', '01', 'com', '09', '20']
# Tema 4:
# ['corp', 'pm', '2000', 'subject', 'cc', 'na', 'ees', 'hou', 'ect', 'enron']

# %%
#DistilBERT
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = DistilBertModel.from_pretrained('distilbert-base-uncased').to('cuda')


def get_bert_embeddings_batch(texts, tokenizer, model, batch_size=16):
    all_embeddings = []
    total_batches = len(texts) // batch_size + 1

    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i + batch_size]

        batch_start_time = time.time()

        inputs = tokenizer(batch_texts, return_tensors='pt', padding=True, truncation=True, max_length=512)
        inputs = {key: val.to('cuda') for key, val in inputs.items()}

        with torch.no_grad():
            outputs = model(**inputs)

        embeddings = outputs.last_hidden_state.mean(dim=1).cpu().numpy()
        all_embeddings.append(embeddings)

        batch_end_time = time.time()
        batch_number = i // batch_size + 1


        print(f"Procesando batch {batch_number}/{total_batches} - Tiempo: {batch_end_time - batch_start_time:.2f} segundos")

    return np.vstack(all_embeddings)

# Aplicar el batch processing para obtener los embeddings
df_filtered['embedding'] = list(get_bert_embeddings_batch(df_filtered['clean_text'].tolist(), tokenizer, model))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Procesando batch 1/4458 - Tiempo: 0.13 segundos
# Procesando batch 2/4458 - Tiempo: 0.17 segundos
# Procesando batch 3/4458 - Tiempo: 0.11 segundos
# Procesando batch 4/4458 - Tiempo: 0.14 segundos
# Procesando batch 5/4458 - Tiempo: 0.10 segundos
# Procesando batch 6/4458 - Tiempo: 0.07 segundos
# Procesando batch 7/4458 - Tiempo: 0.11 segundos
# Procesando batch 8/4458 - Tiempo: 0.08 segundos
# Procesando batch 9/4458 - Tiempo: 0.08 segundos
# Procesando batch 10/4458 - Tiempo: 0.12 segundos
# Procesando batch 11/4458 - Tiempo: 0.09 segundos
# Procesando batch 12/4458 - Tiempo: 0.07 segundos
# Procesando batch 13/4458 - Tiempo: 0.04 segundos
# Procesando batch 14/4458 - Tiempo: 0.08 segundos
# Procesando batch 15/4458 - Tiempo: 0.09 segundos
# Procesando batch 16/4458 - Tiempo: 0.10 segundos
# Procesando batch 17/4458 - Tiempo: 0.16 segundos
# Procesando batch 18/4458 - Tiempo: 0.07 segundos
# Procesando batch 19/4458 - Tiempo: 0.06 segundos
# Procesando batch 20/4458 - Tiempo: 0.16 segundos
# Procesando batch 21/4458 - Tiempo: 0.11 segundos
# Procesando batch 22/4458 - Tiempo: 0.09 segundos
# Procesando batch 23/4458 - Tiempo: 0.11 segundos
# Procesando batch 24/4458 - Tiempo: 0.10 segundos
# Procesando batch 25/4458 - Tiempo: 0.11 segundos
# Procesando batch 26/4458 - Tiempo: 0.09 segundos
# Procesando batch 27/4458 - Tiempo: 0.10 segundos
# Procesando batch 28/4458 - Tiempo: 0.15 segundos
# Procesando batch 29/4458 - Tiempo: 0.17 segundos
# Procesando batch 30/4458 - Tiempo: 0.12 segundos
# Procesando batch 31/4458 - Tiempo: 0.04 segundos
# Procesando batch 32/4458 - Tiempo: 0.09 segundos
# Procesando batch 33/4458 - Tiempo: 0.09 segundos
# Procesando batch 34/4458 - Tiempo: 0.12 segundos
# Procesando batch 35/4458 - Tiempo: 0.10 segundos
# Procesando batch 36/4458 - Tiempo: 0.17 segundos
# Procesando batch 37/4458 - Tiempo: 0.14 segundos
# Procesando batch 38/4458 - Tiempo: 0.11 segundos
# Procesando batch 39/4458 - Tiempo: 0.09 segundos
# Procesando batch 40/4458 - Tiempo: 0.09 segundos
# Procesando batch 41/4458 - Tiempo: 0.11 segundos
# Procesando batch 42/4458 - Tiempo: 0.09 segundos
# Procesando batch 43/4458 - Tiempo: 0.09 segundos
# Procesando batch 44/4458 - Tiempo: 0.11 segundos
# Procesando batch 45/4458 - Tiempo: 0.09 segundos
# Procesando batch 46/4458 - Tiempo: 0.08 segundos
# Procesando batch 47/4458 - Tiempo: 0.04 segundos
# Procesando batch 48/4458 - Tiempo: 0.08 segundos
# Procesando batch 49/4458 - Tiempo: 0.11 segundos
# Procesando batch 50/4458 - Tiempo: 0.09 segundos
# Procesando batch 51/4458 - Tiempo: 0.18 segundos
# Procesando batch 52/4458 - Tiempo: 0.15 segundos
# Procesando batch 53/4458 - Tiempo: 0.07 segundos
# Procesando batch 54/4458 - Tiempo: 0.10 segundos
# Procesando batch 55/4458 - Tiempo: 0.10 segundos
# Procesando batch 56/4458 - Tiempo: 0.16 segundos
# Procesando batch 57/4458 - Tiempo: 0.14 segundos
# Procesando batch 58/4458 - Tiempo: 0.10 segundos
# Procesando batch 59/4458 - Tiempo: 0.10 segundos
# Procesando batch 60/4458 - Tiempo: 0.09 segundos
# Procesando batch 61/4458 - Tiempo: 0.10 segundos
# Procesando batch 62/4458 - Tiempo: 0.10 segundos
# Procesando batch 63/4458 - Tiempo: 0.12 segundos
# Procesando batch 64/4458 - Tiempo: 0.16 segundos
# Procesando batch 65/4458 - Tiempo: 0.11 segundos
# Procesando batch 66/4458 - Tiempo: 0.11 segundos
# Procesando batch 67/4458 - Tiempo: 0.09 segundos
# Procesando batch 68/4458 - Tiempo: 0.08 segundos
# Procesando batch 69/4458 - Tiempo: 0.09 segundos
# Procesando batch 70/4458 - Tiempo: 0.05 segundos
# Procesando batch 71/4458 - Tiempo: 0.22 segundos
# Procesando batch 72/4458 - Tiempo: 0.19 segundos
# Procesando batch 73/4458 - Tiempo: 0.21 segundos
# Procesando batch 74/4458 - Tiempo: 0.15 segundos
# Procesando batch 75/4458 - Tiempo: 0.15 segundos
# Procesando batch 76/4458 - Tiempo: 0.16 segundos
# Procesando batch 77/4458 - Tiempo: 0.16 segundos
# Procesando batch 78/4458 - Tiempo: 0.26 segundos
# Procesando batch 79/4458 - Tiempo: 0.18 segundos
# Procesando batch 80/4458 - Tiempo: 0.19 segundos
# Procesando batch 81/4458 - Tiempo: 0.16 segundos
# Procesando batch 82/4458 - Tiempo: 0.17 segundos
# Procesando batch 83/4458 - Tiempo: 0.18 segundos
# Procesando batch 84/4458 - Tiempo: 0.16 segundos
# Procesando batch 85/4458 - Tiempo: 0.14 segundos
# Procesando batch 86/4458 - Tiempo: 0.15 segundos
# Procesando batch 87/4458 - Tiempo: 0.14 segundos
# Procesando batch 88/4458 - Tiempo: 0.12 segundos
# Procesando batch 89/4458 - Tiempo: 0.10 segundos
# Procesando batch 90/4458 - Tiempo: 0.13 segundos
# Procesando batch 91/4458 - Tiempo: 0.16 segundos
# Procesando batch 92/4458 - Tiempo: 0.15 segundos
# Procesando batch 93/4458 - Tiempo: 0.10 segundos
# Procesando batch 94/4458 - Tiempo: 0.13 segundos
# Procesando batch 95/4458 - Tiempo: 0.16 segundos
# Procesando batch 96/4458 - Tiempo: 0.15 segundos
# Procesando batch 97/4458 - Tiempo: 0.08 segundos
# Procesando batch 98/4458 - Tiempo: 0.10 segundos
# Procesando batch 99/4458 - Tiempo: 0.13 segundos
# Procesando batch 100/4458 - Tiempo: 0.17 segundos
# Procesando batch 101/4458 - Tiempo: 0.12 segundos
# Procesando batch 102/4458 - Tiempo: 0.11 segundos
# Procesando batch 103/4458 - Tiempo: 0.11 segundos
# Procesando batch 104/4458 - Tiempo: 0.11 segundos
# Procesando batch 105/4458 - Tiempo: 0.10 segundos
# Procesando batch 106/4458 - Tiempo: 0.18 segundos
# Procesando batch 107/4458 - Tiempo: 0.10 segundos
# Procesando batch 108/4458 - Tiempo: 0.16 segundos
# Procesando batch 109/4458 - Tiempo: 0.16 segundos
# Procesando batch 110/4458 - Tiempo: 0.13 segundos
# Procesando batch 111/4458 - Tiempo: 0.10 segundos
# Procesando batch 112/4458 - Tiempo: 0.15 segundos
# Procesando batch 113/4458 - Tiempo: 0.16 segundos
# Procesando batch 114/4458 - Tiempo: 0.12 segundos
# Procesando batch 115/4458 - Tiempo: 0.18 segundos
# Procesando batch 116/4458 - Tiempo: 0.14 segundos
# Procesando batch 117/4458 - Tiempo: 0.16 segundos
# Procesando batch 118/4458 - Tiempo: 0.13 segundos
# Procesando batch 119/4458 - Tiempo: 0.13 segundos
# Procesando batch 120/4458 - Tiempo: 0.14 segundos
# Procesando batch 121/4458 - Tiempo: 0.10 segundos
# Procesando batch 122/4458 - Tiempo: 0.14 segundos
# Procesando batch 123/4458 - Tiempo: 0.10 segundos
# Procesando batch 124/4458 - Tiempo: 0.16 segundos
# Procesando batch 125/4458 - Tiempo: 0.09 segundos
# Procesando batch 126/4458 - Tiempo: 0.09 segundos
# Procesando batch 127/4458 - Tiempo: 0.12 segundos
# Procesando batch 128/4458 - Tiempo: 0.13 segundos
# Procesando batch 129/4458 - Tiempo: 0.10 segundos
# Procesando batch 130/4458 - Tiempo: 0.13 segundos
# Procesando batch 131/4458 - Tiempo: 0.12 segundos
# Procesando batch 132/4458 - Tiempo: 0.14 segundos
# Procesando batch 133/4458 - Tiempo: 0.15 segundos
# Procesando batch 134/4458 - Tiempo: 0.16 segundos
# Procesando batch 135/4458 - Tiempo: 0.13 segundos
# Procesando batch 136/4458 - Tiempo: 0.07 segundos
# Procesando batch 137/4458 - Tiempo: 0.10 segundos
# Procesando batch 138/4458 - Tiempo: 0.12 segundos
# Procesando batch 139/4458 - Tiempo: 0.08 segundos
# Procesando batch 140/4458 - Tiempo: 0.09 segundos
# Procesando batch 141/4458 - Tiempo: 0.08 segundos
# Procesando batch 142/4458 - Tiempo: 0.09 segundos
# Procesando batch 143/4458 - Tiempo: 0.11 segundos
# Procesando batch 144/4458 - Tiempo: 0.08 segundos
# Procesando batch 145/4458 - Tiempo: 0.10 segundos
# Procesando batch 146/4458 - Tiempo: 0.04 segundos
# Procesando batch 147/4458 - Tiempo: 0.04 segundos
# Procesando batch 148/4458 - Tiempo: 0.09 segundos
# Procesando batch 149/4458 - Tiempo: 0.09 segundos
# Procesando batch 150/4458 - Tiempo: 0.10 segundos
# Procesando batch 151/4458 - Tiempo: 0.18 segundos
# Procesando batch 152/4458 - Tiempo: 0.07 segundos
# Procesando batch 153/4458 - Tiempo: 0.06 segundos
# Procesando batch 154/4458 - Tiempo: 0.10 segundos
# Procesando batch 155/4458 - Tiempo: 0.16 segundos
# Procesando batch 156/4458 - Tiempo: 0.10 segundos
# Procesando batch 157/4458 - Tiempo: 0.11 segundos
# Procesando batch 158/4458 - Tiempo: 0.09 segundos
# Procesando batch 159/4458 - Tiempo: 0.08 segundos
# Procesando batch 160/4458 - Tiempo: 0.11 segundos
# Procesando batch 161/4458 - Tiempo: 0.10 segundos
# Procesando batch 162/4458 - Tiempo: 0.14 segundos
# Procesando batch 163/4458 - Tiempo: 0.16 segundos
# Procesando batch 164/4458 - Tiempo: 0.13 segundos
# Procesando batch 165/4458 - Tiempo: 0.09 segundos
# Procesando batch 166/4458 - Tiempo: 0.09 segundos
# Procesando batch 167/4458 - Tiempo: 0.09 segundos
# Procesando batch 168/4458 - Tiempo: 0.18 segundos
# Procesando batch 169/4458 - Tiempo: 0.12 segundos
# Procesando batch 170/4458 - Tiempo: 0.10 segundos
# Procesando batch 171/4458 - Tiempo: 0.11 segundos
# Procesando batch 172/4458 - Tiempo: 0.11 segundos
# Procesando batch 173/4458 - Tiempo: 0.11 segundos
# Procesando batch 174/4458 - Tiempo: 0.12 segundos
# Procesando batch 175/4458 - Tiempo: 0.10 segundos
# Procesando batch 176/4458 - Tiempo: 0.11 segundos
# Procesando batch 177/4458 - Tiempo: 0.11 segundos
# Procesando batch 178/4458 - Tiempo: 0.10 segundos
# Procesando batch 179/4458 - Tiempo: 0.12 segundos
# Procesando batch 180/4458 - Tiempo: 0.11 segundos
# Procesando batch 181/4458 - Tiempo: 0.06 segundos
# Procesando batch 182/4458 - Tiempo: 0.10 segundos
# Procesando batch 183/4458 - Tiempo: 0.11 segundos
# Procesando batch 184/4458 - Tiempo: 0.10 segundos
# Procesando batch 185/4458 - Tiempo: 0.10 segundos
# Procesando batch 186/4458 - Tiempo: 0.13 segundos
# Procesando batch 187/4458 - Tiempo: 0.07 segundos
# Procesando batch 188/4458 - Tiempo: 0.12 segundos
# Procesando batch 189/4458 - Tiempo: 0.08 segundos
# Procesando batch 190/4458 - Tiempo: 0.05 segundos
# Procesando batch 191/4458 - Tiempo: 0.11 segundos
# Procesando batch 192/4458 - Tiempo: 0.13 segundos
# Procesando batch 193/4458 - Tiempo: 0.13 segundos
# Procesando batch 194/4458 - Tiempo: 0.10 segundos
# Procesando batch 195/4458 - Tiempo: 0.07 segundos
# Procesando batch 196/4458 - Tiempo: 0.10 segundos
# Procesando batch 197/4458 - Tiempo: 0.13 segundos
# Procesando batch 198/4458 - Tiempo: 0.12 segundos
# Procesando batch 199/4458 - Tiempo: 0.10 segundos
# Procesando batch 200/4458 - Tiempo: 0.13 segundos
# Procesando batch 201/4458 - Tiempo: 0.10 segundos
# Procesando batch 202/4458 - Tiempo: 0.13 segundos
# Procesando batch 203/4458 - Tiempo: 0.17 segundos
# Procesando batch 204/4458 - Tiempo: 0.10 segundos
# Procesando batch 205/4458 - Tiempo: 0.20 segundos
# Procesando batch 206/4458 - Tiempo: 0.21 segundos
# Procesando batch 207/4458 - Tiempo: 0.12 segundos
# Procesando batch 208/4458 - Tiempo: 0.12 segundos
# Procesando batch 209/4458 - Tiempo: 0.10 segundos
# Procesando batch 210/4458 - Tiempo: 0.09 segundos
# Procesando batch 211/4458 - Tiempo: 0.09 segundos
# Procesando batch 212/4458 - Tiempo: 0.13 segundos
# Procesando batch 213/4458 - Tiempo: 0.07 segundos
# Procesando batch 214/4458 - Tiempo: 0.14 segundos
# Procesando batch 215/4458 - Tiempo: 0.10 segundos
# Procesando batch 216/4458 - Tiempo: 0.14 segundos
# Procesando batch 217/4458 - Tiempo: 0.12 segundos
# Procesando batch 218/4458 - Tiempo: 0.13 segundos
# Procesando batch 219/4458 - Tiempo: 0.12 segundos
# Procesando batch 220/4458 - Tiempo: 0.12 segundos
# Procesando batch 221/4458 - Tiempo: 0.15 segundos
# Procesando batch 222/4458 - Tiempo: 0.11 segundos
# Procesando batch 223/4458 - Tiempo: 0.16 segundos
# Procesando batch 224/4458 - Tiempo: 0.22 segundos
# Procesando batch 225/4458 - Tiempo: 0.21 segundos
# Procesando batch 226/4458 - Tiempo: 0.14 segundos
# Procesando batch 227/4458 - Tiempo: 0.13 segundos
# Procesando batch 228/4458 - Tiempo: 0.10 segundos
# Procesando batch 229/4458 - Tiempo: 0.11 segundos
# Procesando batch 230/4458 - Tiempo: 0.11 segundos
# Procesando batch 231/4458 - Tiempo: 0.11 segundos
# Procesando batch 232/4458 - Tiempo: 0.05 segundos
# Procesando batch 233/4458 - Tiempo: 0.16 segundos
# Procesando batch 234/4458 - Tiempo: 0.10 segundos
# Procesando batch 235/4458 - Tiempo: 0.12 segundos
# Procesando batch 236/4458 - Tiempo: 0.12 segundos
# Procesando batch 237/4458 - Tiempo: 0.11 segundos
# Procesando batch 238/4458 - Tiempo: 0.11 segundos
# Procesando batch 239/4458 - Tiempo: 0.11 segundos
# Procesando batch 240/4458 - Tiempo: 0.13 segundos
# Procesando batch 241/4458 - Tiempo: 0.10 segundos
# Procesando batch 242/4458 - Tiempo: 0.12 segundos
# Procesando batch 243/4458 - Tiempo: 0.11 segundos
# Procesando batch 244/4458 - Tiempo: 0.10 segundos
# Procesando batch 245/4458 - Tiempo: 0.10 segundos
# Procesando batch 246/4458 - Tiempo: 0.08 segundos
# Procesando batch 247/4458 - Tiempo: 0.11 segundos
# Procesando batch 248/4458 - Tiempo: 0.11 segundos
# Procesando batch 249/4458 - Tiempo: 0.08 segundos
# Procesando batch 250/4458 - Tiempo: 0.12 segundos
# Procesando batch 251/4458 - Tiempo: 0.09 segundos
# Procesando batch 252/4458 - Tiempo: 0.13 segundos
# Procesando batch 253/4458 - Tiempo: 0.08 segundos
# Procesando batch 254/4458 - Tiempo: 0.09 segundos
# Procesando batch 255/4458 - Tiempo: 0.12 segundos
# Procesando batch 256/4458 - Tiempo: 0.11 segundos
# Procesando batch 257/4458 - Tiempo: 0.14 segundos
# Procesando batch 258/4458 - Tiempo: 0.16 segundos
# Procesando batch 259/4458 - Tiempo: 0.12 segundos
# Procesando batch 260/4458 - Tiempo: 0.12 segundos
# Procesando batch 261/4458 - Tiempo: 0.10 segundos
# Procesando batch 262/4458 - Tiempo: 0.11 segundos
# Procesando batch 263/4458 - Tiempo: 0.13 segundos
# Procesando batch 264/4458 - Tiempo: 0.13 segundos
# Procesando batch 265/4458 - Tiempo: 0.11 segundos
# Procesando batch 266/4458 - Tiempo: 0.16 segundos
# Procesando batch 267/4458 - Tiempo: 0.10 segundos
# Procesando batch 268/4458 - Tiempo: 0.14 segundos
# Procesando batch 269/4458 - Tiempo: 0.17 segundos
# Procesando batch 270/4458 - Tiempo: 0.12 segundos
# Procesando batch 271/4458 - Tiempo: 0.21 segundos
# Procesando batch 272/4458 - Tiempo: 0.21 segundos
# Procesando batch 273/4458 - Tiempo: 0.13 segundos
# Procesando batch 274/4458 - Tiempo: 0.11 segundos
# Procesando batch 275/4458 - Tiempo: 0.11 segundos
# Procesando batch 276/4458 - Tiempo: 0.10 segundos
# Procesando batch 277/4458 - Tiempo: 0.07 segundos
# Procesando batch 278/4458 - Tiempo: 0.15 segundos
# Procesando batch 279/4458 - Tiempo: 0.10 segundos
# Procesando batch 280/4458 - Tiempo: 0.10 segundos
# Procesando batch 281/4458 - Tiempo: 0.21 segundos
# Procesando batch 282/4458 - Tiempo: 0.21 segundos
# Procesando batch 283/4458 - Tiempo: 0.21 segundos
# Procesando batch 284/4458 - Tiempo: 0.20 segundos
# Procesando batch 285/4458 - Tiempo: 0.11 segundos
# Procesando batch 286/4458 - Tiempo: 0.14 segundos
# Procesando batch 287/4458 - Tiempo: 0.16 segundos
# Procesando batch 288/4458 - Tiempo: 0.15 segundos
# Procesando batch 289/4458 - Tiempo: 0.14 segundos
# Procesando batch 290/4458 - Tiempo: 0.15 segundos
# Procesando batch 291/4458 - Tiempo: 0.16 segundos
# Procesando batch 292/4458 - Tiempo: 0.15 segundos
# Procesando batch 293/4458 - Tiempo: 0.20 segundos
# Procesando batch 294/4458 - Tiempo: 0.14 segundos
# Procesando batch 295/4458 - Tiempo: 0.15 segundos
# Procesando batch 296/4458 - Tiempo: 0.19 segundos
# Procesando batch 297/4458 - Tiempo: 0.18 segundos
# Procesando batch 298/4458 - Tiempo: 0.21 segundos
# Procesando batch 299/4458 - Tiempo: 0.11 segundos
# Procesando batch 300/4458 - Tiempo: 0.17 segundos
# Procesando batch 301/4458 - Tiempo: 0.15 segundos
# Procesando batch 302/4458 - Tiempo: 0.21 segundos
# Procesando batch 303/4458 - Tiempo: 0.19 segundos
# Procesando batch 304/4458 - Tiempo: 0.28 segundos
# Procesando batch 305/4458 - Tiempo: 0.30 segundos
# Procesando batch 306/4458 - Tiempo: 0.21 segundos
# Procesando batch 307/4458 - Tiempo: 0.17 segundos
# Procesando batch 308/4458 - Tiempo: 0.32 segundos
# Procesando batch 309/4458 - Tiempo: 0.21 segundos
# Procesando batch 310/4458 - Tiempo: 0.27 segundos
# Procesando batch 311/4458 - Tiempo: 0.15 segundos
# Procesando batch 312/4458 - Tiempo: 0.20 segundos
# Procesando batch 313/4458 - Tiempo: 0.22 segundos
# Procesando batch 314/4458 - Tiempo: 0.16 segundos
# Procesando batch 315/4458 - Tiempo: 0.22 segundos
# Procesando batch 316/4458 - Tiempo: 0.14 segundos
# Procesando batch 317/4458 - Tiempo: 0.13 segundos
# Procesando batch 318/4458 - Tiempo: 0.10 segundos
# Procesando batch 319/4458 - Tiempo: 0.10 segundos
# Procesando batch 320/4458 - Tiempo: 0.11 segundos
# Procesando batch 321/4458 - Tiempo: 0.08 segundos
# Procesando batch 322/4458 - Tiempo: 0.10 segundos
# Procesando batch 323/4458 - Tiempo: 0.12 segundos
# Procesando batch 324/4458 - Tiempo: 0.08 segundos
# Procesando batch 325/4458 - Tiempo: 0.13 segundos
# Procesando batch 326/4458 - Tiempo: 0.08 segundos
# Procesando batch 327/4458 - Tiempo: 0.09 segundos
# Procesando batch 328/4458 - Tiempo: 0.08 segundos
# Procesando batch 329/4458 - Tiempo: 0.08 segundos
# Procesando batch 330/4458 - Tiempo: 0.26 segundos
# Procesando batch 331/4458 - Tiempo: 0.12 segundos
# Procesando batch 332/4458 - Tiempo: 0.12 segundos
# Procesando batch 333/4458 - Tiempo: 0.10 segundos
# Procesando batch 334/4458 - Tiempo: 0.12 segundos
# Procesando batch 335/4458 - Tiempo: 0.13 segundos
# Procesando batch 336/4458 - Tiempo: 0.11 segundos
# Procesando batch 337/4458 - Tiempo: 0.10 segundos
# Procesando batch 338/4458 - Tiempo: 0.10 segundos
# Procesando batch 339/4458 - Tiempo: 0.09 segundos
# Procesando batch 340/4458 - Tiempo: 0.15 segundos
# Procesando batch 341/4458 - Tiempo: 0.19 segundos
# Procesando batch 342/4458 - Tiempo: 0.15 segundos
# Procesando batch 343/4458 - Tiempo: 0.10 segundos
# Procesando batch 344/4458 - Tiempo: 0.18 segundos
# Procesando batch 345/4458 - Tiempo: 0.11 segundos
# Procesando batch 346/4458 - Tiempo: 0.10 segundos
# Procesando batch 347/4458 - Tiempo: 0.12 segundos
# Procesando batch 348/4458 - Tiempo: 0.18 segundos
# Procesando batch 349/4458 - Tiempo: 0.12 segundos
# Procesando batch 350/4458 - Tiempo: 0.11 segundos
# Procesando batch 351/4458 - Tiempo: 0.09 segundos
# Procesando batch 352/4458 - Tiempo: 0.13 segundos
# Procesando batch 353/4458 - Tiempo: 0.16 segundos
# Procesando batch 354/4458 - Tiempo: 0.14 segundos
# Procesando batch 355/4458 - Tiempo: 0.12 segundos
# Procesando batch 356/4458 - Tiempo: 0.19 segundos
# Procesando batch 357/4458 - Tiempo: 0.15 segundos
# Procesando batch 358/4458 - Tiempo: 0.23 segundos
# Procesando batch 359/4458 - Tiempo: 0.09 segundos
# Procesando batch 360/4458 - Tiempo: 0.14 segundos
# Procesando batch 361/4458 - Tiempo: 0.12 segundos
# Procesando batch 362/4458 - Tiempo: 0.11 segundos
# Procesando batch 363/4458 - Tiempo: 0.11 segundos
# Procesando batch 364/4458 - Tiempo: 0.13 segundos
# Procesando batch 365/4458 - Tiempo: 0.14 segundos
# Procesando batch 366/4458 - Tiempo: 0.18 segundos
# Procesando batch 367/4458 - Tiempo: 0.16 segundos
# Procesando batch 368/4458 - Tiempo: 0.11 segundos
# Procesando batch 369/4458 - Tiempo: 0.11 segundos
# Procesando batch 370/4458 - Tiempo: 0.12 segundos
# Procesando batch 371/4458 - Tiempo: 0.08 segundos
# Procesando batch 372/4458 - Tiempo: 0.15 segundos
# Procesando batch 373/4458 - Tiempo: 0.13 segundos
# Procesando batch 374/4458 - Tiempo: 0.12 segundos
# Procesando batch 375/4458 - Tiempo: 0.12 segundos
# Procesando batch 376/4458 - Tiempo: 0.10 segundos
# Procesando batch 377/4458 - Tiempo: 0.11 segundos
# Procesando batch 378/4458 - Tiempo: 0.12 segundos
# Procesando batch 379/4458 - Tiempo: 0.10 segundos
# Procesando batch 380/4458 - Tiempo: 0.14 segundos
# Procesando batch 381/4458 - Tiempo: 0.09 segundos
# Procesando batch 382/4458 - Tiempo: 0.19 segundos
# Procesando batch 383/4458 - Tiempo: 0.08 segundos
# Procesando batch 384/4458 - Tiempo: 0.10 segundos
# Procesando batch 385/4458 - Tiempo: 0.16 segundos
# Procesando batch 386/4458 - Tiempo: 0.10 segundos
# Procesando batch 387/4458 - Tiempo: 0.09 segundos
# Procesando batch 388/4458 - Tiempo: 0.09 segundos
# Procesando batch 389/4458 - Tiempo: 0.11 segundos
# Procesando batch 390/4458 - Tiempo: 0.13 segundos
# Procesando batch 391/4458 - Tiempo: 0.12 segundos
# Procesando batch 392/4458 - Tiempo: 0.14 segundos
# Procesando batch 393/4458 - Tiempo: 0.21 segundos
# Procesando batch 394/4458 - Tiempo: 0.10 segundos
# Procesando batch 395/4458 - Tiempo: 0.11 segundos
# Procesando batch 396/4458 - Tiempo: 0.11 segundos
# Procesando batch 397/4458 - Tiempo: 0.12 segundos
# Procesando batch 398/4458 - Tiempo: 0.11 segundos
# Procesando batch 399/4458 - Tiempo: 0.11 segundos
# Procesando batch 400/4458 - Tiempo: 0.11 segundos
# Procesando batch 401/4458 - Tiempo: 0.09 segundos
# Procesando batch 402/4458 - Tiempo: 0.12 segundos
# Procesando batch 403/4458 - Tiempo: 0.09 segundos
# Procesando batch 404/4458 - Tiempo: 0.13 segundos
# Procesando batch 405/4458 - Tiempo: 0.10 segundos
# Procesando batch 406/4458 - Tiempo: 0.10 segundos
# Procesando batch 407/4458 - Tiempo: 0.10 segundos
# Procesando batch 408/4458 - Tiempo: 0.07 segundos
# Procesando batch 409/4458 - Tiempo: 0.11 segundos
# Procesando batch 410/4458 - Tiempo: 0.09 segundos
# Procesando batch 411/4458 - Tiempo: 0.10 segundos
# Procesando batch 412/4458 - Tiempo: 0.13 segundos
# Procesando batch 413/4458 - Tiempo: 0.09 segundos
# Procesando batch 414/4458 - Tiempo: 0.11 segundos
# Procesando batch 415/4458 - Tiempo: 0.08 segundos
# Procesando batch 416/4458 - Tiempo: 0.08 segundos
# Procesando batch 417/4458 - Tiempo: 0.12 segundos
# Procesando batch 418/4458 - Tiempo: 0.15 segundos
# Procesando batch 419/4458 - Tiempo: 0.11 segundos
# Procesando batch 420/4458 - Tiempo: 0.09 segundos
# Procesando batch 421/4458 - Tiempo: 0.06 segundos
# Procesando batch 422/4458 - Tiempo: 0.13 segundos
# Procesando batch 423/4458 - Tiempo: 0.13 segundos
# Procesando batch 424/4458 - Tiempo: 0.12 segundos
# Procesando batch 425/4458 - Tiempo: 0.10 segundos
# Procesando batch 426/4458 - Tiempo: 0.12 segundos
# Procesando batch 427/4458 - Tiempo: 0.10 segundos
# Procesando batch 428/4458 - Tiempo: 0.16 segundos
# Procesando batch 429/4458 - Tiempo: 0.15 segundos
# Procesando batch 430/4458 - Tiempo: 0.18 segundos
# Procesando batch 431/4458 - Tiempo: 0.22 segundos
# Procesando batch 432/4458 - Tiempo: 0.13 segundos
# Procesando batch 433/4458 - Tiempo: 0.13 segundos
# Procesando batch 434/4458 - Tiempo: 0.11 segundos
# Procesando batch 435/4458 - Tiempo: 0.06 segundos
# Procesando batch 436/4458 - Tiempo: 0.10 segundos
# Procesando batch 437/4458 - Tiempo: 0.11 segundos
# Procesando batch 438/4458 - Tiempo: 0.12 segundos
# Procesando batch 439/4458 - Tiempo: 0.08 segundos
# Procesando batch 440/4458 - Tiempo: 0.10 segundos
# Procesando batch 441/4458 - Tiempo: 0.11 segundos
# Procesando batch 442/4458 - Tiempo: 0.16 segundos
# Procesando batch 443/4458 - Tiempo: 0.14 segundos
# Procesando batch 444/4458 - Tiempo: 0.10 segundos
# Procesando batch 445/4458 - Tiempo: 0.14 segundos
# Procesando batch 446/4458 - Tiempo: 0.13 segundos
# Procesando batch 447/4458 - Tiempo: 0.13 segundos
# Procesando batch 448/4458 - Tiempo: 0.15 segundos
# Procesando batch 449/4458 - Tiempo: 0.10 segundos
# Procesando batch 450/4458 - Tiempo: 0.22 segundos
# Procesando batch 451/4458 - Tiempo: 0.49 segundos
# Procesando batch 452/4458 - Tiempo: 0.23 segundos
# Procesando batch 453/4458 - Tiempo: 0.24 segundos
# Procesando batch 454/4458 - Tiempo: 0.23 segundos
# Procesando batch 455/4458 - Tiempo: 0.23 segundos
# Procesando batch 456/4458 - Tiempo: 0.28 segundos
# Procesando batch 457/4458 - Tiempo: 0.53 segundos
# Procesando batch 458/4458 - Tiempo: 0.25 segundos
# Procesando batch 459/4458 - Tiempo: 0.98 segundos
# Procesando batch 460/4458 - Tiempo: 0.08 segundos
# Procesando batch 461/4458 - Tiempo: 0.16 segundos
# Procesando batch 462/4458 - Tiempo: 0.11 segundos
# Procesando batch 463/4458 - Tiempo: 0.16 segundos
# Procesando batch 464/4458 - Tiempo: 0.19 segundos
# Procesando batch 465/4458 - Tiempo: 0.12 segundos
# Procesando batch 466/4458 - Tiempo: 0.23 segundos
# Procesando batch 467/4458 - Tiempo: 0.19 segundos
# Procesando batch 468/4458 - Tiempo: 0.12 segundos
# Procesando batch 469/4458 - Tiempo: 0.13 segundos
# Procesando batch 470/4458 - Tiempo: 0.11 segundos
# Procesando batch 471/4458 - Tiempo: 0.16 segundos
# Procesando batch 472/4458 - Tiempo: 0.11 segundos
# Procesando batch 473/4458 - Tiempo: 0.13 segundos
# Procesando batch 474/4458 - Tiempo: 0.13 segundos
# Procesando batch 475/4458 - Tiempo: 0.13 segundos
# Procesando batch 476/4458 - Tiempo: 0.12 segundos
# Procesando batch 477/4458 - Tiempo: 0.13 segundos
# Procesando batch 478/4458 - Tiempo: 0.12 segundos
# Procesando batch 479/4458 - Tiempo: 0.17 segundos
# Procesando batch 480/4458 - Tiempo: 0.09 segundos
# Procesando batch 481/4458 - Tiempo: 0.09 segundos
# Procesando batch 482/4458 - Tiempo: 0.12 segundos
# Procesando batch 483/4458 - Tiempo: 0.17 segundos
# Procesando batch 484/4458 - Tiempo: 0.13 segundos
# Procesando batch 485/4458 - Tiempo: 0.15 segundos
# Procesando batch 486/4458 - Tiempo: 0.21 segundos
# Procesando batch 487/4458 - Tiempo: 0.12 segundos
# Procesando batch 488/4458 - Tiempo: 0.11 segundos
# Procesando batch 489/4458 - Tiempo: 0.11 segundos
# Procesando batch 490/4458 - Tiempo: 0.15 segundos
# Procesando batch 491/4458 - Tiempo: 0.13 segundos
# Procesando batch 492/4458 - Tiempo: 0.14 segundos
# Procesando batch 493/4458 - Tiempo: 0.26 segundos
# Procesando batch 494/4458 - Tiempo: 0.15 segundos
# Procesando batch 495/4458 - Tiempo: 0.12 segundos
# Procesando batch 496/4458 - Tiempo: 0.11 segundos
# Procesando batch 497/4458 - Tiempo: 0.16 segundos
# Procesando batch 498/4458 - Tiempo: 0.13 segundos
# Procesando batch 499/4458 - Tiempo: 0.13 segundos
# Procesando batch 500/4458 - Tiempo: 0.14 segundos
# Procesando batch 501/4458 - Tiempo: 0.14 segundos
# Procesando batch 502/4458 - Tiempo: 0.18 segundos
# Procesando batch 503/4458 - Tiempo: 0.13 segundos
# Procesando batch 504/4458 - Tiempo: 0.18 segundos
# Procesando batch 505/4458 - Tiempo: 0.10 segundos
# Procesando batch 506/4458 - Tiempo: 0.12 segundos
# Procesando batch 507/4458 - Tiempo: 0.14 segundos
# Procesando batch 508/4458 - Tiempo: 0.13 segundos
# Procesando batch 509/4458 - Tiempo: 0.15 segundos
# Procesando batch 510/4458 - Tiempo: 0.28 segundos
# Procesando batch 511/4458 - Tiempo: 0.13 segundos
# Procesando batch 512/4458 - Tiempo: 0.16 segundos
# Procesando batch 513/4458 - Tiempo: 0.11 segundos
# Procesando batch 514/4458 - Tiempo: 0.20 segundos
# Procesando batch 515/4458 - Tiempo: 0.20 segundos
# Procesando batch 516/4458 - Tiempo: 0.12 segundos
# Procesando batch 517/4458 - Tiempo: 0.13 segundos
# Procesando batch 518/4458 - Tiempo: 0.11 segundos
# Procesando batch 519/4458 - Tiempo: 0.17 segundos
# Procesando batch 520/4458 - Tiempo: 0.09 segundos
# Procesando batch 521/4458 - Tiempo: 0.16 segundos
# Procesando batch 522/4458 - Tiempo: 0.13 segundos
# Procesando batch 523/4458 - Tiempo: 0.12 segundos
# Procesando batch 524/4458 - Tiempo: 0.14 segundos
# Procesando batch 525/4458 - Tiempo: 0.17 segundos
# Procesando batch 526/4458 - Tiempo: 0.13 segundos
# Procesando batch 527/4458 - Tiempo: 0.06 segundos
# Procesando batch 528/4458 - Tiempo: 0.12 segundos
# Procesando batch 529/4458 - Tiempo: 0.11 segundos
# Procesando batch 530/4458 - Tiempo: 0.11 segundos
# Procesando batch 531/4458 - Tiempo: 0.12 segundos
# Procesando batch 532/4458 - Tiempo: 0.10 segundos
# Procesando batch 533/4458 - Tiempo: 0.08 segundos
# Procesando batch 534/4458 - Tiempo: 0.07 segundos
# Procesando batch 535/4458 - Tiempo: 0.11 segundos
# Procesando batch 536/4458 - Tiempo: 0.12 segundos
# Procesando batch 537/4458 - Tiempo: 0.08 segundos
# Procesando batch 538/4458 - Tiempo: 0.13 segundos
# Procesando batch 539/4458 - Tiempo: 0.10 segundos
# Procesando batch 540/4458 - Tiempo: 0.12 segundos
# Procesando batch 541/4458 - Tiempo: 0.17 segundos
# Procesando batch 542/4458 - Tiempo: 0.11 segundos
# Procesando batch 543/4458 - Tiempo: 0.12 segundos
# Procesando batch 544/4458 - Tiempo: 0.13 segundos
# Procesando batch 545/4458 - Tiempo: 0.08 segundos
# Procesando batch 546/4458 - Tiempo: 0.20 segundos
# Procesando batch 547/4458 - Tiempo: 0.10 segundos
# Procesando batch 548/4458 - Tiempo: 0.13 segundos
# Procesando batch 549/4458 - Tiempo: 0.09 segundos
# Procesando batch 550/4458 - Tiempo: 0.07 segundos
# Procesando batch 551/4458 - Tiempo: 0.20 segundos
# Procesando batch 552/4458 - Tiempo: 0.12 segundos
# Procesando batch 553/4458 - Tiempo: 0.10 segundos
# Procesando batch 554/4458 - Tiempo: 0.12 segundos
# Procesando batch 555/4458 - Tiempo: 0.13 segundos
# Procesando batch 556/4458 - Tiempo: 0.09 segundos
# Procesando batch 557/4458 - Tiempo: 0.11 segundos
# Procesando batch 558/4458 - Tiempo: 0.14 segundos
# Procesando batch 559/4458 - Tiempo: 0.12 segundos
# Procesando batch 560/4458 - Tiempo: 0.13 segundos
# Procesando batch 561/4458 - Tiempo: 0.10 segundos
# Procesando batch 562/4458 - Tiempo: 0.10 segundos
# Procesando batch 563/4458 - Tiempo: 0.11 segundos
# Procesando batch 564/4458 - Tiempo: 0.13 segundos
# Procesando batch 565/4458 - Tiempo: 0.12 segundos
# Procesando batch 566/4458 - Tiempo: 0.14 segundos
# Procesando batch 567/4458 - Tiempo: 0.12 segundos
# Procesando batch 568/4458 - Tiempo: 0.11 segundos
# Procesando batch 569/4458 - Tiempo: 0.10 segundos
# Procesando batch 570/4458 - Tiempo: 0.09 segundos
# Procesando batch 571/4458 - Tiempo: 0.09 segundos
# Procesando batch 572/4458 - Tiempo: 0.10 segundos
# Procesando batch 573/4458 - Tiempo: 0.11 segundos
# Procesando batch 574/4458 - Tiempo: 0.12 segundos
# Procesando batch 575/4458 - Tiempo: 0.08 segundos
# Procesando batch 576/4458 - Tiempo: 0.10 segundos
# Procesando batch 577/4458 - Tiempo: 0.10 segundos
# Procesando batch 578/4458 - Tiempo: 0.10 segundos
# Procesando batch 579/4458 - Tiempo: 0.17 segundos
# Procesando batch 580/4458 - Tiempo: 0.12 segundos
# Procesando batch 581/4458 - Tiempo: 0.11 segundos
# Procesando batch 582/4458 - Tiempo: 0.11 segundos
# Procesando batch 583/4458 - Tiempo: 0.12 segundos
# Procesando batch 584/4458 - Tiempo: 0.11 segundos
# Procesando batch 585/4458 - Tiempo: 0.13 segundos
# Procesando batch 586/4458 - Tiempo: 0.11 segundos
# Procesando batch 587/4458 - Tiempo: 0.11 segundos
# Procesando batch 588/4458 - Tiempo: 0.11 segundos
# Procesando batch 589/4458 - Tiempo: 0.05 segundos
# Procesando batch 590/4458 - Tiempo: 0.11 segundos
# Procesando batch 591/4458 - Tiempo: 0.09 segundos
# Procesando batch 592/4458 - Tiempo: 0.10 segundos
# Procesando batch 593/4458 - Tiempo: 0.09 segundos
# Procesando batch 594/4458 - Tiempo: 0.08 segundos
# Procesando batch 595/4458 - Tiempo: 0.08 segundos
# Procesando batch 596/4458 - Tiempo: 0.10 segundos
# Procesando batch 597/4458 - Tiempo: 0.09 segundos
# Procesando batch 598/4458 - Tiempo: 0.13 segundos
# Procesando batch 599/4458 - Tiempo: 0.13 segundos
# Procesando batch 600/4458 - Tiempo: 0.10 segundos
# Procesando batch 601/4458 - Tiempo: 0.10 segundos
# Procesando batch 602/4458 - Tiempo: 0.12 segundos
# Procesando batch 603/4458 - Tiempo: 0.10 segundos
# Procesando batch 604/4458 - Tiempo: 0.11 segundos
# Procesando batch 605/4458 - Tiempo: 0.15 segundos
# Procesando batch 606/4458 - Tiempo: 0.11 segundos
# Procesando batch 607/4458 - Tiempo: 0.12 segundos
# Procesando batch 608/4458 - Tiempo: 0.14 segundos
# Procesando batch 609/4458 - Tiempo: 0.12 segundos
# Procesando batch 610/4458 - Tiempo: 0.10 segundos
# Procesando batch 611/4458 - Tiempo: 0.12 segundos
# Procesando batch 612/4458 - Tiempo: 0.12 segundos
# Procesando batch 613/4458 - Tiempo: 0.10 segundos
# Procesando batch 614/4458 - Tiempo: 0.09 segundos
# Procesando batch 615/4458 - Tiempo: 0.12 segundos
# Procesando batch 616/4458 - Tiempo: 0.07 segundos
# Procesando batch 617/4458 - Tiempo: 0.11 segundos
# Procesando batch 618/4458 - Tiempo: 0.14 segundos
# Procesando batch 619/4458 - Tiempo: 0.15 segundos
# Procesando batch 620/4458 - Tiempo: 0.12 segundos
# Procesando batch 621/4458 - Tiempo: 0.10 segundos
# Procesando batch 622/4458 - Tiempo: 0.09 segundos
# Procesando batch 623/4458 - Tiempo: 0.06 segundos
# Procesando batch 624/4458 - Tiempo: 0.09 segundos
# Procesando batch 625/4458 - Tiempo: 0.09 segundos
# Procesando batch 626/4458 - Tiempo: 0.08 segundos
# Procesando batch 627/4458 - Tiempo: 0.10 segundos
# Procesando batch 628/4458 - Tiempo: 0.10 segundos
# Procesando batch 629/4458 - Tiempo: 0.12 segundos
# Procesando batch 630/4458 - Tiempo: 0.12 segundos
# Procesando batch 631/4458 - Tiempo: 0.15 segundos
# Procesando batch 632/4458 - Tiempo: 0.07 segundos
# Procesando batch 633/4458 - Tiempo: 0.12 segundos
# Procesando batch 634/4458 - Tiempo: 0.13 segundos
# Procesando batch 635/4458 - Tiempo: 0.11 segundos
# Procesando batch 636/4458 - Tiempo: 0.11 segundos
# Procesando batch 637/4458 - Tiempo: 0.15 segundos
# Procesando batch 638/4458 - Tiempo: 0.10 segundos
# Procesando batch 639/4458 - Tiempo: 0.12 segundos
# Procesando batch 640/4458 - Tiempo: 0.12 segundos
# Procesando batch 641/4458 - Tiempo: 0.14 segundos
# Procesando batch 642/4458 - Tiempo: 0.07 segundos
# Procesando batch 643/4458 - Tiempo: 0.11 segundos
# Procesando batch 644/4458 - Tiempo: 0.13 segundos
# Procesando batch 645/4458 - Tiempo: 0.12 segundos
# Procesando batch 646/4458 - Tiempo: 0.10 segundos
# Procesando batch 647/4458 - Tiempo: 0.10 segundos
# Procesando batch 648/4458 - Tiempo: 0.12 segundos
# Procesando batch 649/4458 - Tiempo: 0.12 segundos
# Procesando batch 650/4458 - Tiempo: 0.10 segundos
# Procesando batch 651/4458 - Tiempo: 0.17 segundos
# Procesando batch 652/4458 - Tiempo: 0.06 segundos
# Procesando batch 653/4458 - Tiempo: 0.21 segundos
# Procesando batch 654/4458 - Tiempo: 0.10 segundos
# Procesando batch 655/4458 - Tiempo: 0.16 segundos
# Procesando batch 656/4458 - Tiempo: 0.13 segundos
# Procesando batch 657/4458 - Tiempo: 0.09 segundos
# Procesando batch 658/4458 - Tiempo: 0.21 segundos
# Procesando batch 659/4458 - Tiempo: 0.11 segundos
# Procesando batch 660/4458 - Tiempo: 0.11 segundos
# Procesando batch 661/4458 - Tiempo: 0.12 segundos
# Procesando batch 662/4458 - Tiempo: 0.12 segundos
# Procesando batch 663/4458 - Tiempo: 0.09 segundos
# Procesando batch 664/4458 - Tiempo: 0.10 segundos
# Procesando batch 665/4458 - Tiempo: 0.13 segundos
# Procesando batch 666/4458 - Tiempo: 0.10 segundos
# Procesando batch 667/4458 - Tiempo: 0.15 segundos
# Procesando batch 668/4458 - Tiempo: 0.10 segundos
# Procesando batch 669/4458 - Tiempo: 0.11 segundos
# Procesando batch 670/4458 - Tiempo: 0.10 segundos
# Procesando batch 671/4458 - Tiempo: 0.13 segundos
# Procesando batch 672/4458 - Tiempo: 0.12 segundos
# Procesando batch 673/4458 - Tiempo: 0.12 segundos
# Procesando batch 674/4458 - Tiempo: 0.14 segundos
# Procesando batch 675/4458 - Tiempo: 0.08 segundos
# Procesando batch 676/4458 - Tiempo: 0.13 segundos
# Procesando batch 677/4458 - Tiempo: 0.09 segundos
# Procesando batch 678/4458 - Tiempo: 0.09 segundos
# Procesando batch 679/4458 - Tiempo: 0.17 segundos
# Procesando batch 680/4458 - Tiempo: 0.18 segundos
# Procesando batch 681/4458 - Tiempo: 0.19 segundos
# Procesando batch 682/4458 - Tiempo: 0.36 segundos
# Procesando batch 683/4458 - Tiempo: 0.17 segundos
# Procesando batch 684/4458 - Tiempo: 0.27 segundos
# Procesando batch 685/4458 - Tiempo: 0.15 segundos
# Procesando batch 686/4458 - Tiempo: 0.27 segundos
# Procesando batch 687/4458 - Tiempo: 0.26 segundos
# Procesando batch 688/4458 - Tiempo: 0.25 segundos
# Procesando batch 689/4458 - Tiempo: 0.12 segundos
# Procesando batch 690/4458 - Tiempo: 0.25 segundos
# Procesando batch 691/4458 - Tiempo: 0.15 segundos
# Procesando batch 692/4458 - Tiempo: 0.25 segundos
# Procesando batch 693/4458 - Tiempo: 0.16 segundos
# Procesando batch 694/4458 - Tiempo: 0.22 segundos
# Procesando batch 695/4458 - Tiempo: 0.27 segundos
# Procesando batch 696/4458 - Tiempo: 0.14 segundos
# Procesando batch 697/4458 - Tiempo: 0.21 segundos
# Procesando batch 698/4458 - Tiempo: 0.21 segundos
# Procesando batch 699/4458 - Tiempo: 0.26 segundos
# Procesando batch 700/4458 - Tiempo: 0.26 segundos
# Procesando batch 701/4458 - Tiempo: 0.25 segundos
# Procesando batch 702/4458 - Tiempo: 0.14 segundos
# Procesando batch 703/4458 - Tiempo: 0.25 segundos
# Procesando batch 704/4458 - Tiempo: 0.32 segundos
# Procesando batch 705/4458 - Tiempo: 0.13 segundos
# Procesando batch 706/4458 - Tiempo: 0.23 segundos
# Procesando batch 707/4458 - Tiempo: 0.11 segundos
# Procesando batch 708/4458 - Tiempo: 0.11 segundos
# Procesando batch 709/4458 - Tiempo: 0.18 segundos
# Procesando batch 710/4458 - Tiempo: 0.13 segundos
# Procesando batch 711/4458 - Tiempo: 0.10 segundos
# Procesando batch 712/4458 - Tiempo: 0.11 segundos
# Procesando batch 713/4458 - Tiempo: 0.12 segundos
# Procesando batch 714/4458 - Tiempo: 0.12 segundos
# Procesando batch 715/4458 - Tiempo: 0.12 segundos
# Procesando batch 716/4458 - Tiempo: 0.13 segundos
# Procesando batch 717/4458 - Tiempo: 0.19 segundos
# Procesando batch 718/4458 - Tiempo: 0.29 segundos
# Procesando batch 719/4458 - Tiempo: 0.18 segundos
# Procesando batch 720/4458 - Tiempo: 0.20 segundos
# Procesando batch 721/4458 - Tiempo: 0.42 segundos
# Procesando batch 722/4458 - Tiempo: 0.47 segundos
# Procesando batch 723/4458 - Tiempo: 0.32 segundos
# Procesando batch 724/4458 - Tiempo: 0.28 segundos
# Procesando batch 725/4458 - Tiempo: 0.90 segundos
# Procesando batch 726/4458 - Tiempo: 1.18 segundos
# Procesando batch 727/4458 - Tiempo: 0.76 segundos
# Procesando batch 728/4458 - Tiempo: 1.36 segundos
# Procesando batch 729/4458 - Tiempo: 0.59 segundos
# Procesando batch 730/4458 - Tiempo: 0.57 segundos
# Procesando batch 731/4458 - Tiempo: 0.30 segundos
# Procesando batch 732/4458 - Tiempo: 0.61 segundos
# Procesando batch 733/4458 - Tiempo: 0.20 segundos
# Procesando batch 734/4458 - Tiempo: 0.67 segundos
# Procesando batch 735/4458 - Tiempo: 0.25 segundos
# Procesando batch 736/4458 - Tiempo: 0.76 segundos
# Procesando batch 737/4458 - Tiempo: 0.32 segundos
# Procesando batch 738/4458 - Tiempo: 0.25 segundos
# Procesando batch 739/4458 - Tiempo: 0.22 segundos
# Procesando batch 740/4458 - Tiempo: 0.39 segundos
# Procesando batch 741/4458 - Tiempo: 0.13 segundos
# Procesando batch 742/4458 - Tiempo: 0.22 segundos
# Procesando batch 743/4458 - Tiempo: 0.12 segundos
# Procesando batch 744/4458 - Tiempo: 0.20 segundos
# Procesando batch 745/4458 - Tiempo: 0.14 segundos
# Procesando batch 746/4458 - Tiempo: 0.12 segundos
# Procesando batch 747/4458 - Tiempo: 0.22 segundos
# Procesando batch 748/4458 - Tiempo: 0.29 segundos
# Procesando batch 749/4458 - Tiempo: 0.31 segundos
# Procesando batch 750/4458 - Tiempo: 0.22 segundos
# Procesando batch 751/4458 - Tiempo: 0.12 segundos
# Procesando batch 752/4458 - Tiempo: 0.19 segundos
# Procesando batch 753/4458 - Tiempo: 0.10 segundos
# Procesando batch 754/4458 - Tiempo: 0.08 segundos
# Procesando batch 755/4458 - Tiempo: 0.12 segundos
# Procesando batch 756/4458 - Tiempo: 0.10 segundos
# Procesando batch 757/4458 - Tiempo: 0.10 segundos
# Procesando batch 758/4458 - Tiempo: 0.10 segundos
# Procesando batch 759/4458 - Tiempo: 0.16 segundos
# Procesando batch 760/4458 - Tiempo: 0.13 segundos
# Procesando batch 761/4458 - Tiempo: 0.18 segundos
# Procesando batch 762/4458 - Tiempo: 0.12 segundos
# Procesando batch 763/4458 - Tiempo: 0.10 segundos
# Procesando batch 764/4458 - Tiempo: 0.08 segundos
# Procesando batch 765/4458 - Tiempo: 0.07 segundos
# Procesando batch 766/4458 - Tiempo: 0.04 segundos
# Procesando batch 767/4458 - Tiempo: 0.07 segundos
# Procesando batch 768/4458 - Tiempo: 0.08 segundos
# Procesando batch 769/4458 - Tiempo: 0.09 segundos
# Procesando batch 770/4458 - Tiempo: 0.12 segundos
# Procesando batch 771/4458 - Tiempo: 0.05 segundos
# Procesando batch 772/4458 - Tiempo: 0.14 segundos
# Procesando batch 773/4458 - Tiempo: 0.18 segundos
# Procesando batch 774/4458 - Tiempo: 0.10 segundos
# Procesando batch 775/4458 - Tiempo: 0.14 segundos
# Procesando batch 776/4458 - Tiempo: 0.30 segundos
# Procesando batch 777/4458 - Tiempo: 0.24 segundos
# Procesando batch 778/4458 - Tiempo: 0.22 segundos
# Procesando batch 779/4458 - Tiempo: 0.13 segundos
# Procesando batch 780/4458 - Tiempo: 0.25 segundos
# Procesando batch 781/4458 - Tiempo: 0.28 segundos
# Procesando batch 782/4458 - Tiempo: 0.24 segundos
# Procesando batch 783/4458 - Tiempo: 0.21 segundos
# Procesando batch 784/4458 - Tiempo: 0.20 segundos
# Procesando batch 785/4458 - Tiempo: 0.20 segundos
# Procesando batch 786/4458 - Tiempo: 0.14 segundos
# Procesando batch 787/4458 - Tiempo: 0.18 segundos
# Procesando batch 788/4458 - Tiempo: 0.24 segundos
# Procesando batch 789/4458 - Tiempo: 0.12 segundos
# Procesando batch 790/4458 - Tiempo: 0.24 segundos
# Procesando batch 791/4458 - Tiempo: 0.10 segundos
# Procesando batch 792/4458 - Tiempo: 0.23 segundos
# Procesando batch 793/4458 - Tiempo: 0.20 segundos
# Procesando batch 794/4458 - Tiempo: 0.18 segundos
# Procesando batch 795/4458 - Tiempo: 0.20 segundos
# Procesando batch 796/4458 - Tiempo: 0.28 segundos
# Procesando batch 797/4458 - Tiempo: 0.17 segundos
# Procesando batch 798/4458 - Tiempo: 0.16 segundos
# Procesando batch 799/4458 - Tiempo: 0.25 segundos
# Procesando batch 800/4458 - Tiempo: 0.18 segundos
# Procesando batch 801/4458 - Tiempo: 0.17 segundos
# Procesando batch 802/4458 - Tiempo: 0.27 segundos
# Procesando batch 803/4458 - Tiempo: 0.13 segundos
# Procesando batch 804/4458 - Tiempo: 0.27 segundos
# Procesando batch 805/4458 - Tiempo: 0.56 segundos
# Procesando batch 806/4458 - Tiempo: 0.25 segundos
# Procesando batch 807/4458 - Tiempo: 0.61 segundos
# Procesando batch 808/4458 - Tiempo: 1.05 segundos
# Procesando batch 809/4458 - Tiempo: 0.70 segundos
# Procesando batch 810/4458 - Tiempo: 0.54 segundos
# Procesando batch 811/4458 - Tiempo: 0.16 segundos
# Procesando batch 812/4458 - Tiempo: 0.32 segundos
# Procesando batch 813/4458 - Tiempo: 0.12 segundos
# Procesando batch 814/4458 - Tiempo: 0.15 segundos
# Procesando batch 815/4458 - Tiempo: 0.12 segundos
# Procesando batch 816/4458 - Tiempo: 0.23 segundos
# Procesando batch 817/4458 - Tiempo: 0.12 segundos
# Procesando batch 818/4458 - Tiempo: 0.24 segundos
# Procesando batch 819/4458 - Tiempo: 0.17 segundos
# Procesando batch 820/4458 - Tiempo: 0.36 segundos
# Procesando batch 821/4458 - Tiempo: 0.18 segundos
# Procesando batch 822/4458 - Tiempo: 0.31 segundos
# Procesando batch 823/4458 - Tiempo: 0.28 segundos
# Procesando batch 824/4458 - Tiempo: 0.24 segundos
# Procesando batch 825/4458 - Tiempo: 0.25 segundos
# Procesando batch 826/4458 - Tiempo: 0.19 segundos
# Procesando batch 827/4458 - Tiempo: 0.24 segundos
# Procesando batch 828/4458 - Tiempo: 0.25 segundos
# Procesando batch 829/4458 - Tiempo: 0.27 segundos
# Procesando batch 830/4458 - Tiempo: 0.18 segundos
# Procesando batch 831/4458 - Tiempo: 0.24 segundos
# Procesando batch 832/4458 - Tiempo: 0.20 segundos
# Procesando batch 833/4458 - Tiempo: 0.26 segundos
# Procesando batch 834/4458 - Tiempo: 0.27 segundos
# Procesando batch 835/4458 - Tiempo: 0.26 segundos
# Procesando batch 836/4458 - Tiempo: 0.18 segundos
# Procesando batch 837/4458 - Tiempo: 0.28 segundos
# Procesando batch 838/4458 - Tiempo: 0.25 segundos
# Procesando batch 839/4458 - Tiempo: 0.15 segundos
# Procesando batch 840/4458 - Tiempo: 0.09 segundos
# Procesando batch 841/4458 - Tiempo: 0.15 segundos
# Procesando batch 842/4458 - Tiempo: 0.11 segundos
# Procesando batch 843/4458 - Tiempo: 0.07 segundos
# Procesando batch 844/4458 - Tiempo: 0.11 segundos
# Procesando batch 845/4458 - Tiempo: 0.10 segundos
# Procesando batch 846/4458 - Tiempo: 0.12 segundos
# Procesando batch 847/4458 - Tiempo: 0.07 segundos
# Procesando batch 848/4458 - Tiempo: 0.12 segundos
# Procesando batch 849/4458 - Tiempo: 0.13 segundos
# Procesando batch 850/4458 - Tiempo: 0.14 segundos
# Procesando batch 851/4458 - Tiempo: 0.10 segundos
# Procesando batch 852/4458 - Tiempo: 0.12 segundos
# Procesando batch 853/4458 - Tiempo: 0.12 segundos
# Procesando batch 854/4458 - Tiempo: 0.10 segundos
# Procesando batch 855/4458 - Tiempo: 0.20 segundos
# Procesando batch 856/4458 - Tiempo: 0.12 segundos
# Procesando batch 857/4458 - Tiempo: 0.10 segundos
# Procesando batch 858/4458 - Tiempo: 0.12 segundos
# Procesando batch 859/4458 - Tiempo: 0.13 segundos
# Procesando batch 860/4458 - Tiempo: 0.09 segundos
# Procesando batch 861/4458 - Tiempo: 0.11 segundos
# Procesando batch 862/4458 - Tiempo: 0.12 segundos
# Procesando batch 863/4458 - Tiempo: 0.10 segundos
# Procesando batch 864/4458 - Tiempo: 0.15 segundos
# Procesando batch 865/4458 - Tiempo: 0.10 segundos
# Procesando batch 866/4458 - Tiempo: 0.10 segundos
# Procesando batch 867/4458 - Tiempo: 0.11 segundos
# Procesando batch 868/4458 - Tiempo: 0.11 segundos
# Procesando batch 869/4458 - Tiempo: 0.10 segundos
# Procesando batch 870/4458 - Tiempo: 0.15 segundos
# Procesando batch 871/4458 - Tiempo: 0.14 segundos
# Procesando batch 872/4458 - Tiempo: 0.10 segundos
# Procesando batch 873/4458 - Tiempo: 0.12 segundos
# Procesando batch 874/4458 - Tiempo: 0.09 segundos
# Procesando batch 875/4458 - Tiempo: 0.09 segundos
# Procesando batch 876/4458 - Tiempo: 0.08 segundos
# Procesando batch 877/4458 - Tiempo: 0.12 segundos
# Procesando batch 878/4458 - Tiempo: 0.10 segundos
# Procesando batch 879/4458 - Tiempo: 0.19 segundos
# Procesando batch 880/4458 - Tiempo: 0.11 segundos
# Procesando batch 881/4458 - Tiempo: 0.11 segundos
# Procesando batch 882/4458 - Tiempo: 0.12 segundos
# Procesando batch 883/4458 - Tiempo: 0.13 segundos
# Procesando batch 884/4458 - Tiempo: 0.11 segundos
# Procesando batch 885/4458 - Tiempo: 0.12 segundos
# Procesando batch 886/4458 - Tiempo: 0.10 segundos
# Procesando batch 887/4458 - Tiempo: 0.12 segundos
# Procesando batch 888/4458 - Tiempo: 0.09 segundos
# Procesando batch 889/4458 - Tiempo: 0.09 segundos
# Procesando batch 890/4458 - Tiempo: 0.12 segundos
# Procesando batch 891/4458 - Tiempo: 0.08 segundos
# Procesando batch 892/4458 - Tiempo: 0.09 segundos
# Procesando batch 893/4458 - Tiempo: 0.09 segundos
# Procesando batch 894/4458 - Tiempo: 0.09 segundos
# Procesando batch 895/4458 - Tiempo: 0.08 segundos
# Procesando batch 896/4458 - Tiempo: 0.10 segundos
# Procesando batch 897/4458 - Tiempo: 0.09 segundos
# Procesando batch 898/4458 - Tiempo: 0.10 segundos
# Procesando batch 899/4458 - Tiempo: 0.13 segundos
# Procesando batch 900/4458 - Tiempo: 0.12 segundos
# Procesando batch 901/4458 - Tiempo: 0.09 segundos
# Procesando batch 902/4458 - Tiempo: 0.11 segundos
# Procesando batch 903/4458 - Tiempo: 0.12 segundos
# Procesando batch 904/4458 - Tiempo: 0.10 segundos
# Procesando batch 905/4458 - Tiempo: 0.11 segundos
# Procesando batch 906/4458 - Tiempo: 0.15 segundos
# Procesando batch 907/4458 - Tiempo: 0.10 segundos
# Procesando batch 908/4458 - Tiempo: 0.12 segundos
# Procesando batch 909/4458 - Tiempo: 0.13 segundos
# Procesando batch 910/4458 - Tiempo: 0.14 segundos
# Procesando batch 911/4458 - Tiempo: 0.07 segundos
# Procesando batch 912/4458 - Tiempo: 0.12 segundos
# Procesando batch 913/4458 - Tiempo: 0.12 segundos
# Procesando batch 914/4458 - Tiempo: 0.11 segundos
# Procesando batch 915/4458 - Tiempo: 0.09 segundos
# Procesando batch 916/4458 - Tiempo: 0.10 segundos
# Procesando batch 917/4458 - Tiempo: 0.12 segundos
# Procesando batch 918/4458 - Tiempo: 0.10 segundos
# Procesando batch 919/4458 - Tiempo: 0.13 segundos
# Procesando batch 920/4458 - Tiempo: 0.07 segundos
# Procesando batch 921/4458 - Tiempo: 0.11 segundos
# Procesando batch 922/4458 - Tiempo: 0.18 segundos
# Procesando batch 923/4458 - Tiempo: 0.13 segundos
# Procesando batch 924/4458 - Tiempo: 0.08 segundos
# Procesando batch 925/4458 - Tiempo: 0.12 segundos
# Procesando batch 926/4458 - Tiempo: 0.16 segundos
# Procesando batch 927/4458 - Tiempo: 0.14 segundos
# Procesando batch 928/4458 - Tiempo: 0.12 segundos
# Procesando batch 929/4458 - Tiempo: 0.17 segundos
# Procesando batch 930/4458 - Tiempo: 0.17 segundos
# Procesando batch 931/4458 - Tiempo: 0.14 segundos
# Procesando batch 932/4458 - Tiempo: 0.12 segundos
# Procesando batch 933/4458 - Tiempo: 0.10 segundos
# Procesando batch 934/4458 - Tiempo: 0.16 segundos
# Procesando batch 935/4458 - Tiempo: 0.15 segundos
# Procesando batch 936/4458 - Tiempo: 0.19 segundos
# Procesando batch 937/4458 - Tiempo: 3.59 segundos
# Procesando batch 938/4458 - Tiempo: 0.43 segundos
# Procesando batch 939/4458 - Tiempo: 0.46 segundos
# Procesando batch 940/4458 - Tiempo: 0.39 segundos
# Procesando batch 941/4458 - Tiempo: 0.26 segundos
# Procesando batch 942/4458 - Tiempo: 0.38 segundos
# Procesando batch 943/4458 - Tiempo: 0.35 segundos
# Procesando batch 944/4458 - Tiempo: 0.51 segundos
# Procesando batch 945/4458 - Tiempo: 0.29 segundos
# Procesando batch 946/4458 - Tiempo: 0.23 segundos
# Procesando batch 947/4458 - Tiempo: 0.32 segundos
# Procesando batch 948/4458 - Tiempo: 0.41 segundos
# Procesando batch 949/4458 - Tiempo: 0.19 segundos
# Procesando batch 950/4458 - Tiempo: 0.36 segundos
# Procesando batch 951/4458 - Tiempo: 0.16 segundos
# Procesando batch 952/4458 - Tiempo: 0.26 segundos
# Procesando batch 953/4458 - Tiempo: 0.37 segundos
# Procesando batch 954/4458 - Tiempo: 0.18 segundos
# ...
# Procesando batch 4154/4458 - Tiempo: 0.17 segundos
# Procesando batch 4155/4458 - Tiempo: 0.10 segundos
# Procesando batch 4156/4458 - Tiempo: 0.11 segundos
# Procesando batch 4157/4458 - Tiempo: 0.07 segundos
# Procesando batch 4158/4458 - Tiempo: 0.11 segundos
# Procesando batch 4159/4458 - Tiempo: 0.09 segundos
# Procesando batch 4160/4458 - Tiempo: 0.09 segundos
# Procesando batch 4161/4458 - Tiempo: 0.03 segundos
# Procesando batch 4162/4458 - Tiempo: 0.09 segundos
# Procesando batch 4163/4458 - Tiempo: 0.11 segundos
# Procesando batch 4164/4458 - Tiempo: 0.06 segundos
# Procesando batch 4165/4458 - Tiempo: 0.09 segundos
# Procesando batch 4166/4458 - Tiempo: 0.09 segundos
# Procesando batch 4167/4458 - Tiempo: 0.12 segundos
# Procesando batch 4168/4458 - Tiempo: 0.07 segundos
# Procesando batch 4169/4458 - Tiempo: 0.10 segundos
# Procesando batch 4170/4458 - Tiempo: 0.09 segundos
# Procesando batch 4171/4458 - Tiempo: 0.10 segundos
# Procesando batch 4172/4458 - Tiempo: 0.07 segundos
# Procesando batch 4173/4458 - Tiempo: 0.09 segundos
# Procesando batch 4174/4458 - Tiempo: 0.11 segundos
# Procesando batch 4175/4458 - Tiempo: 0.09 segundos
# Procesando batch 4176/4458 - Tiempo: 0.11 segundos
# Procesando batch 4177/4458 - Tiempo: 0.22 segundos
# Procesando batch 4178/4458 - Tiempo: 0.12 segundos
# Procesando batch 4179/4458 - Tiempo: 0.21 segundos
# Procesando batch 4180/4458 - Tiempo: 0.12 segundos
# Procesando batch 4181/4458 - Tiempo: 0.11 segundos
# Procesando batch 4182/4458 - Tiempo: 0.13 segundos
# Procesando batch 4183/4458 - Tiempo: 0.11 segundos
# Procesando batch 4184/4458 - Tiempo: 0.12 segundos
# Procesando batch 4185/4458 - Tiempo: 0.13 segundos
# Procesando batch 4186/4458 - Tiempo: 0.09 segundos
# Procesando batch 4187/4458 - Tiempo: 0.29 segundos
# Procesando batch 4188/4458 - Tiempo: 0.10 segundos
# Procesando batch 4189/4458 - Tiempo: 0.17 segundos
# Procesando batch 4190/4458 - Tiempo: 0.14 segundos
# Procesando batch 4191/4458 - Tiempo: 0.11 segundos
# Procesando batch 4192/4458 - Tiempo: 0.17 segundos
# Procesando batch 4193/4458 - Tiempo: 0.15 segundos
# Procesando batch 4194/4458 - Tiempo: 0.17 segundos
# Procesando batch 4195/4458 - Tiempo: 0.11 segundos
# Procesando batch 4196/4458 - Tiempo: 0.11 segundos
# Procesando batch 4197/4458 - Tiempo: 0.13 segundos
# Procesando batch 4198/4458 - Tiempo: 0.22 segundos
# Procesando batch 4199/4458 - Tiempo: 0.12 segundos
# Procesando batch 4200/4458 - Tiempo: 0.15 segundos
# Procesando batch 4201/4458 - Tiempo: 0.12 segundos
# Procesando batch 4202/4458 - Tiempo: 0.11 segundos
# Procesando batch 4203/4458 - Tiempo: 0.19 segundos
# Procesando batch 4204/4458 - Tiempo: 0.11 segundos
# Procesando batch 4205/4458 - Tiempo: 0.12 segundos
# Procesando batch 4206/4458 - Tiempo: 0.10 segundos
# Procesando batch 4207/4458 - Tiempo: 0.12 segundos
# Procesando batch 4208/4458 - Tiempo: 0.14 segundos
# Procesando batch 4209/4458 - Tiempo: 0.15 segundos
# Procesando batch 4210/4458 - Tiempo: 0.08 segundos
# Procesando batch 4211/4458 - Tiempo: 0.12 segundos
# Procesando batch 4212/4458 - Tiempo: 0.09 segundos
# Procesando batch 4213/4458 - Tiempo: 0.13 segundos
# Procesando batch 4214/4458 - Tiempo: 0.12 segundos
# Procesando batch 4215/4458 - Tiempo: 0.10 segundos
# Procesando batch 4216/4458 - Tiempo: 0.06 segundos
# Procesando batch 4217/4458 - Tiempo: 0.31 segundos
# Procesando batch 4218/4458 - Tiempo: 0.38 segundos
# Procesando batch 4219/4458 - Tiempo: 0.32 segundos
# Procesando batch 4220/4458 - Tiempo: 0.52 segundos
# Procesando batch 4221/4458 - Tiempo: 0.16 segundos
# Procesando batch 4222/4458 - Tiempo: 0.12 segundos
# Procesando batch 4223/4458 - Tiempo: 0.11 segundos
# Procesando batch 4224/4458 - Tiempo: 0.33 segundos
# Procesando batch 4225/4458 - Tiempo: 0.37 segundos
# Procesando batch 4226/4458 - Tiempo: 0.30 segundos
# Procesando batch 4227/4458 - Tiempo: 0.18 segundos
# Procesando batch 4228/4458 - Tiempo: 0.44 segundos
# Procesando batch 4229/4458 - Tiempo: 0.22 segundos
# Procesando batch 4230/4458 - Tiempo: 0.21 segundos
# Procesando batch 4231/4458 - Tiempo: 0.24 segundos
# Procesando batch 4232/4458 - Tiempo: 0.43 segundos
# Procesando batch 4233/4458 - Tiempo: 0.37 segundos
# Procesando batch 4234/4458 - Tiempo: 0.38 segundos
# Procesando batch 4235/4458 - Tiempo: 0.33 segundos
# Procesando batch 4236/4458 - Tiempo: 0.22 segundos
# Procesando batch 4237/4458 - Tiempo: 0.17 segundos
# Procesando batch 4238/4458 - Tiempo: 0.22 segundos
# Procesando batch 4239/4458 - Tiempo: 0.14 segundos
# Procesando batch 4240/4458 - Tiempo: 0.11 segundos
# Procesando batch 4241/4458 - Tiempo: 0.49 segundos
# Procesando batch 4242/4458 - Tiempo: 0.17 segundos
# Procesando batch 4243/4458 - Tiempo: 0.13 segundos
# Procesando batch 4244/4458 - Tiempo: 0.13 segundos
# Procesando batch 4245/4458 - Tiempo: 0.19 segundos
# Procesando batch 4246/4458 - Tiempo: 0.25 segundos
# Procesando batch 4247/4458 - Tiempo: 0.31 segundos
# Procesando batch 4248/4458 - Tiempo: 0.20 segundos
# Procesando batch 4249/4458 - Tiempo: 0.11 segundos
# Procesando batch 4250/4458 - Tiempo: 0.39 segundos
# Procesando batch 4251/4458 - Tiempo: 0.32 segundos
# Procesando batch 4252/4458 - Tiempo: 0.26 segundos
# Procesando batch 4253/4458 - Tiempo: 0.13 segundos
# Procesando batch 4254/4458 - Tiempo: 0.12 segundos
# Procesando batch 4255/4458 - Tiempo: 0.10 segundos
# Procesando batch 4256/4458 - Tiempo: 0.09 segundos
# Procesando batch 4257/4458 - Tiempo: 0.06 segundos
# Procesando batch 4258/4458 - Tiempo: 0.09 segundos
# Procesando batch 4259/4458 - Tiempo: 0.10 segundos
# Procesando batch 4260/4458 - Tiempo: 0.02 segundos
# Procesando batch 4261/4458 - Tiempo: 0.09 segundos
# Procesando batch 4262/4458 - Tiempo: 0.04 segundos
# Procesando batch 4263/4458 - Tiempo: 0.04 segundos
# Procesando batch 4264/4458 - Tiempo: 0.02 segundos
# Procesando batch 4265/4458 - Tiempo: 0.07 segundos
# Procesando batch 4266/4458 - Tiempo: 0.08 segundos
# Procesando batch 4267/4458 - Tiempo: 0.05 segundos
# Procesando batch 4268/4458 - Tiempo: 0.03 segundos
# Procesando batch 4269/4458 - Tiempo: 0.10 segundos
# Procesando batch 4270/4458 - Tiempo: 0.04 segundos
# Procesando batch 4271/4458 - Tiempo: 0.02 segundos
# Procesando batch 4272/4458 - Tiempo: 0.08 segundos
# Procesando batch 4273/4458 - Tiempo: 0.06 segundos
# Procesando batch 4274/4458 - Tiempo: 0.02 segundos
# Procesando batch 4275/4458 - Tiempo: 0.01 segundos
# Procesando batch 4276/4458 - Tiempo: 0.02 segundos
# Procesando batch 4277/4458 - Tiempo: 0.04 segundos
# Procesando batch 4278/4458 - Tiempo: 0.09 segundos
# Procesando batch 4279/4458 - Tiempo: 0.02 segundos
# Procesando batch 4280/4458 - Tiempo: 0.02 segundos
# Procesando batch 4281/4458 - Tiempo: 0.09 segundos
# Procesando batch 4282/4458 - Tiempo: 0.10 segundos
# Procesando batch 4283/4458 - Tiempo: 0.09 segundos
# Procesando batch 4284/4458 - Tiempo: 0.11 segundos
# Procesando batch 4285/4458 - Tiempo: 0.06 segundos
# Procesando batch 4286/4458 - Tiempo: 0.11 segundos
# Procesando batch 4287/4458 - Tiempo: 0.28 segundos
# Procesando batch 4288/4458 - Tiempo: 0.31 segundos
# Procesando batch 4289/4458 - Tiempo: 0.25 segundos
# Procesando batch 4290/4458 - Tiempo: 0.38 segundos
# Procesando batch 4291/4458 - Tiempo: 0.35 segundos
# Procesando batch 4292/4458 - Tiempo: 24.81 segundos
# Procesando batch 4293/4458 - Tiempo: 0.32 segundos
# Procesando batch 4294/4458 - Tiempo: 0.26 segundos
# Procesando batch 4295/4458 - Tiempo: 0.22 segundos
# Procesando batch 4296/4458 - Tiempo: 0.15 segundos
# Procesando batch 4297/4458 - Tiempo: 0.06 segundos
# Procesando batch 4298/4458 - Tiempo: 0.08 segundos
# Procesando batch 4299/4458 - Tiempo: 0.08 segundos
# Procesando batch 4300/4458 - Tiempo: 0.10 segundos
# Procesando batch 4301/4458 - Tiempo: 0.07 segundos
# Procesando batch 4302/4458 - Tiempo: 0.09 segundos
# Procesando batch 4303/4458 - Tiempo: 0.08 segundos
# Procesando batch 4304/4458 - Tiempo: 0.08 segundos
# Procesando batch 4305/4458 - Tiempo: 0.12 segundos
# Procesando batch 4306/4458 - Tiempo: 0.08 segundos
# Procesando batch 4307/4458 - Tiempo: 0.10 segundos
# Procesando batch 4308/4458 - Tiempo: 0.02 segundos
# Procesando batch 4309/4458 - Tiempo: 0.09 segundos
# Procesando batch 4310/4458 - Tiempo: 0.04 segundos
# Procesando batch 4311/4458 - Tiempo: 0.14 segundos
# Procesando batch 4312/4458 - Tiempo: 0.16 segundos
# Procesando batch 4313/4458 - Tiempo: 0.12 segundos
# Procesando batch 4314/4458 - Tiempo: 0.11 segundos
# Procesando batch 4315/4458 - Tiempo: 0.11 segundos
# Procesando batch 4316/4458 - Tiempo: 0.12 segundos
# Procesando batch 4317/4458 - Tiempo: 0.18 segundos
# Procesando batch 4318/4458 - Tiempo: 0.10 segundos
# Procesando batch 4319/4458 - Tiempo: 0.15 segundos
# Procesando batch 4320/4458 - Tiempo: 0.12 segundos
# Procesando batch 4321/4458 - Tiempo: 0.09 segundos
# Procesando batch 4322/4458 - Tiempo: 0.12 segundos
# Procesando batch 4323/4458 - Tiempo: 0.11 segundos
# Procesando batch 4324/4458 - Tiempo: 0.11 segundos
# Procesando batch 4325/4458 - Tiempo: 0.15 segundos
# Procesando batch 4326/4458 - Tiempo: 0.10 segundos
# Procesando batch 4327/4458 - Tiempo: 0.08 segundos
# Procesando batch 4328/4458 - Tiempo: 0.13 segundos
# Procesando batch 4329/4458 - Tiempo: 0.10 segundos
# Procesando batch 4330/4458 - Tiempo: 0.18 segundos
# Procesando batch 4331/4458 - Tiempo: 0.25 segundos
# Procesando batch 4332/4458 - Tiempo: 0.23 segundos
# Procesando batch 4333/4458 - Tiempo: 0.14 segundos
# Procesando batch 4334/4458 - Tiempo: 0.13 segundos
# Procesando batch 4335/4458 - Tiempo: 0.20 segundos
# Procesando batch 4336/4458 - Tiempo: 0.16 segundos
# Procesando batch 4337/4458 - Tiempo: 0.23 segundos
# Procesando batch 4338/4458 - Tiempo: 0.15 segundos
# Procesando batch 4339/4458 - Tiempo: 0.17 segundos
# Procesando batch 4340/4458 - Tiempo: 0.09 segundos
# Procesando batch 4341/4458 - Tiempo: 0.15 segundos
# Procesando batch 4342/4458 - Tiempo: 0.12 segundos
# Procesando batch 4343/4458 - Tiempo: 0.22 segundos
# Procesando batch 4344/4458 - Tiempo: 0.11 segundos
# Procesando batch 4345/4458 - Tiempo: 0.12 segundos
# Procesando batch 4346/4458 - Tiempo: 0.05 segundos
# Procesando batch 4347/4458 - Tiempo: 0.14 segundos
# Procesando batch 4348/4458 - Tiempo: 0.10 segundos
# Procesando batch 4349/4458 - Tiempo: 0.07 segundos
# Procesando batch 4350/4458 - Tiempo: 0.04 segundos
# Procesando batch 4351/4458 - Tiempo: 0.02 segundos
# Procesando batch 4352/4458 - Tiempo: 0.08 segundos
# Procesando batch 4353/4458 - Tiempo: 0.06 segundos
# Procesando batch 4354/4458 - Tiempo: 0.05 segundos
# Procesando batch 4355/4458 - Tiempo: 0.09 segundos
# Procesando batch 4356/4458 - Tiempo: 0.08 segundos
# Procesando batch 4357/4458 - Tiempo: 0.04 segundos
# Procesando batch 4358/4458 - Tiempo: 0.02 segundos
# Procesando batch 4359/4458 - Tiempo: 0.08 segundos
# Procesando batch 4360/4458 - Tiempo: 0.06 segundos
# Procesando batch 4361/4458 - Tiempo: 0.01 segundos
# Procesando batch 4362/4458 - Tiempo: 0.03 segundos
# Procesando batch 4363/4458 - Tiempo: 0.04 segundos
# Procesando batch 4364/4458 - Tiempo: 0.09 segundos
# Procesando batch 4365/4458 - Tiempo: 0.11 segundos
# Procesando batch 4366/4458 - Tiempo: 0.02 segundos
# Procesando batch 4367/4458 - Tiempo: 0.02 segundos
# Procesando batch 4368/4458 - Tiempo: 0.09 segundos
# Procesando batch 4369/4458 - Tiempo: 0.10 segundos
# Procesando batch 4370/4458 - Tiempo: 0.08 segundos
# Procesando batch 4371/4458 - Tiempo: 0.06 segundos
# Procesando batch 4372/4458 - Tiempo: 0.08 segundos
# Procesando batch 4373/4458 - Tiempo: 0.04 segundos
# Procesando batch 4374/4458 - Tiempo: 0.23 segundos
# Procesando batch 4375/4458 - Tiempo: 0.36 segundos
# Procesando batch 4376/4458 - Tiempo: 0.40 segundos
# Procesando batch 4377/4458 - Tiempo: 0.50 segundos
# Procesando batch 4378/4458 - Tiempo: 0.17 segundos
# Procesando batch 4379/4458 - Tiempo: 0.16 segundos
# Procesando batch 4380/4458 - Tiempo: 0.18 segundos
# Procesando batch 4381/4458 - Tiempo: 0.23 segundos
# Procesando batch 4382/4458 - Tiempo: 0.15 segundos
# Procesando batch 4383/4458 - Tiempo: 0.13 segundos
# Procesando batch 4384/4458 - Tiempo: 0.21 segundos
# Procesando batch 4385/4458 - Tiempo: 0.13 segundos
# Procesando batch 4386/4458 - Tiempo: 0.45 segundos
# Procesando batch 4387/4458 - Tiempo: 0.32 segundos
# Procesando batch 4388/4458 - Tiempo: 0.16 segundos
# Procesando batch 4389/4458 - Tiempo: 0.38 segundos
# Procesando batch 4390/4458 - Tiempo: 0.21 segundos
# Procesando batch 4391/4458 - Tiempo: 0.23 segundos
# Procesando batch 4392/4458 - Tiempo: 0.18 segundos
# Procesando batch 4393/4458 - Tiempo: 0.19 segundos
# Procesando batch 4394/4458 - Tiempo: 0.25 segundos
# Procesando batch 4395/4458 - Tiempo: 0.14 segundos
# Procesando batch 4396/4458 - Tiempo: 0.27 segundos
# Procesando batch 4397/4458 - Tiempo: 0.27 segundos
# Procesando batch 4398/4458 - Tiempo: 0.35 segundos
# Procesando batch 4399/4458 - Tiempo: 0.35 segundos
# Procesando batch 4400/4458 - Tiempo: 0.37 segundos
# Procesando batch 4401/4458 - Tiempo: 0.36 segundos
# Procesando batch 4402/4458 - Tiempo: 0.65 segundos
# Procesando batch 4403/4458 - Tiempo: 0.74 segundos
# Procesando batch 4404/4458 - Tiempo: 0.73 segundos
# Procesando batch 4405/4458 - Tiempo: 0.68 segundos
# Procesando batch 4406/4458 - Tiempo: 0.21 segundos
# Procesando batch 4407/4458 - Tiempo: 0.58 segundos
# Procesando batch 4408/4458 - Tiempo: 0.22 segundos
# Procesando batch 4409/4458 - Tiempo: 0.29 segundos
# Procesando batch 4410/4458 - Tiempo: 0.46 segundos
# Procesando batch 4411/4458 - Tiempo: 0.52 segundos
# Procesando batch 4412/4458 - Tiempo: 0.38 segundos
# Procesando batch 4413/4458 - Tiempo: 0.47 segundos
# Procesando batch 4414/4458 - Tiempo: 0.36 segundos
# Procesando batch 4415/4458 - Tiempo: 0.40 segundos
# Procesando batch 4416/4458 - Tiempo: 0.21 segundos
# Procesando batch 4417/4458 - Tiempo: 0.16 segundos
# Procesando batch 4418/4458 - Tiempo: 0.17 segundos
# Procesando batch 4419/4458 - Tiempo: 0.19 segundos
# Procesando batch 4420/4458 - Tiempo: 0.23 segundos
# Procesando batch 4421/4458 - Tiempo: 0.41 segundos
# Procesando batch 4422/4458 - Tiempo: 0.34 segundos
# Procesando batch 4423/4458 - Tiempo: 0.09 segundos
# Procesando batch 4424/4458 - Tiempo: 0.11 segundos
# Procesando batch 4425/4458 - Tiempo: 0.14 segundos
# Procesando batch 4426/4458 - Tiempo: 0.10 segundos
# Procesando batch 4427/4458 - Tiempo: 0.11 segundos
# Procesando batch 4428/4458 - Tiempo: 0.12 segundos
# Procesando batch 4429/4458 - Tiempo: 0.12 segundos
# Procesando batch 4430/4458 - Tiempo: 0.11 segundos
# Procesando batch 4431/4458 - Tiempo: 0.16 segundos
# Procesando batch 4432/4458 - Tiempo: 0.11 segundos
# Procesando batch 4433/4458 - Tiempo: 0.10 segundos
# Procesando batch 4434/4458 - Tiempo: 0.15 segundos
# Procesando batch 4435/4458 - Tiempo: 0.12 segundos
# Procesando batch 4436/4458 - Tiempo: 0.09 segundos
# Procesando batch 4437/4458 - Tiempo: 0.22 segundos
# Procesando batch 4438/4458 - Tiempo: 0.10 segundos
# Procesando batch 4439/4458 - Tiempo: 0.12 segundos
# Procesando batch 4440/4458 - Tiempo: 0.07 segundos
# Procesando batch 4441/4458 - Tiempo: 0.15 segundos
# Procesando batch 4442/4458 - Tiempo: 0.13 segundos
# Procesando batch 4443/4458 - Tiempo: 0.10 segundos
# Procesando batch 4444/4458 - Tiempo: 0.13 segundos
# Procesando batch 4445/4458 - Tiempo: 0.13 segundos
# Procesando batch 4446/4458 - Tiempo: 0.20 segundos
# Procesando batch 4447/4458 - Tiempo: 0.15 segundos
# Procesando batch 4448/4458 - Tiempo: 0.10 segundos
# Procesando batch 4449/4458 - Tiempo: 0.13 segundos
# Procesando batch 4450/4458 - Tiempo: 0.11 segundos
# Procesando batch 4451/4458 - Tiempo: 0.12 segundos
# Procesando batch 4452/4458 - Tiempo: 0.11 segundos
# Procesando batch 4453/4458 - Tiempo: 0.13 segundos
# Procesando batch 4454/4458 - Tiempo: 0.09 segundos
# Procesando batch 4455/4458 - Tiempo: 0.12 segundos
# Procesando batch 4456/4458 - Tiempo: 0.11 segundos
# Procesando batch 4457/4458 - Tiempo: 0.12 segundos
# Procesando batch 4458/4458 - Tiempo: 0.05 segundos
# <ipython-input-63-5dff3b8755c0>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['embedding'] = list(get_bert_embeddings_batch(df_filtered['clean_text'].tolist(), tokenizer, model))

# %%
# Embeddigs a array para clustering
embeddings_array = np.vstack(df_filtered['embedding'].values)

kmeans = KMeans(n_clusters=3, random_state=42)
df_filtered['cluster'] = kmeans.fit_predict(embeddings_array)

for cluster in range(3):
    print(f'\nCorreos en cluster {cluster}:')
    print(df_filtered[df_filtered['cluster'] == cluster]['clean_text'].head())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Correos en cluster 0:
# 9     , -- -- -- -- -- -- -- -- -- -- -- Forwarded P...
# 12    , -- -- -- -- -- -- -- -- -- -- -- Forwarded P...
# 13    , -- -- -- -- -- -- -- -- -- -- -- Forwarded P...
# 16    , -- -- -- -- -- -- -- -- -- -- -- Forwarded P...
# 25    , -- -- -- -- -- -- -- -- -- -- -- Forwarded P...
# Name: clean_text, dtype: object
#
# Correos en cluster 1:
# 1    , Traveling business meeting takes fun trip . ...
# 2                     , test successful . way go ! ! !
# 3    , Randy , , , send schedule salary level every...
# 4                       , Lets shoot Tuesday 11:45 . ]
# 5    , Greg , , , either next Tuesday Thursday ? , ...
# Name: clean_text, dtype: object
#
# Correos en cluster 2:
# 18    , -- -- -- -- -- -- -- -- -- -- -- Forwarded P...
# 19    , -- -- -- -- -- -- -- -- -- -- -- Forwarded P...
# 23    , -- -- -- -- -- -- -- -- -- -- -- Forwarded P...
# 24    , Liane , , , discussed yesterday , concerned ...
# 30    , -- -- -- -- -- -- -- -- -- -- -- Forwarded P...
# Name: clean_text, dtype: object
# <ipython-input-64-4b6c0c791e24>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['cluster'] = kmeans.fit_predict(embeddings_array)

# %%
# Interacciones más comunes
df_interactions = df_filtered.groupby(['sender', 'recipient1']).size().reset_index(name='counts')

print(df_interactions.sort_values(by='counts', ascending=False).head())
# Out:
#                               sender                       recipient1  counts
# 9055            pete.davis@enron.com             pete.davis@enron.com     627
# 3298             eric.bass@enron.com          shanna.husser@enron.com     472
# 10453           sally.beck@enron.com         patti.thompson@enron.com     388
# 3045   enron.announcements@enron.com            all.houston@enron.com     360
# 5065         jeff.dasovich@enron.com  nancy.sellers@robertmondavi.com     348

# %%
prompt = """
A growing romance between two employees during a major project. The story unfolds in The Enron offices, where long hours and stressful deadlines bring employees closer.
Eric Bass and Shanna Husser are working together on a challenging task that requires constant collaboration. As the pressure increases, they begin to realize that their connection goes beyond work.
Eric notices how supportive Shanna has been through the tough times, and slowly, a deeper bond forms between them. Despite the office chaos, they find small moments of connection...
"""

# %%
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

inputs = tokenizer(prompt, return_tensors='pt')
outputs = model.generate(inputs['input_ids'], max_length=300, num_return_sequences=1)

generated_story = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(generated_story)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A growing romance between two employees during a major project. The story unfolds in The Enron offices, where long hours and stressful deadlines bring employees closer.
# Eric Bass and Shanna Husser are working together on a challenging task that requires constant collaboration. As the pressure increases, they begin to realize that their connection goes beyond work.
# Eric notices how supportive Shanna has been through the tough times, and slowly, a deeper bond forms between them. Despite the office chaos, they find small moments of connection...
# Eric and Shanna are working together on a challenging task that requires constant collaboration. As the pressure increases, they begin to realize that their connection goes beyond work.
# Eric and Shanna are working together on a challenging task that requires constant collaboration. As the pressure increases, they begin to realize that their connection goes beyond work.
# Eric and Shanna are working together on a challenging task that requires constant collaboration. As the pressure increases, they begin to realize that their connection goes beyond work.
# Eric and Shanna are working together on a challenging task that requires constant collaboration. As the pressure increases, they begin to realize that their connection goes beyond work.
# Eric and Shanna are working together on a challenging task that requires constant collaboration. As the pressure increases, they begin to realize that their connection goes beyond work.
# Eric and Shanna are working together on a challenging task that requires constant collaboration. As the pressure increases, they begin to realize that their connection goes beyond work

# %%
# Ajustar generacion
outputs = model.generate(
    inputs['input_ids'],
    max_length=500,
    num_return_sequences=1,
    temperature=0.7,  # Creatividad
    top_p=0.9,
    repetition_penalty=1.5
)

generated_story = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(generated_story)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:567: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:572: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A growing romance between two employees during a major project. The story unfolds in The Enron offices, where long hours and stressful deadlines bring employees closer.
# Eric Bass and Shanna Husser are working together on a challenging task that requires constant collaboration. As the pressure increases, they begin to realize that their connection goes beyond work.
# Eric notices how supportive Shanna has been through the tough times, and slowly, a deeper bond forms between them. Despite the office chaos, they find small moments of connection...
# Shannan is an employee at A&E who works with Eric's boss for several months before she leaves her job as senior vice president overseeing sales operations (the company also owns his personal email account). She finds herself constantly being asked questions about what it takes when you're not doing anything but talking or writing code - something which can be difficult if your team isn't paying attention!

# %%
selected_cluster = 0

cluster_emails = df_filtered[df_filtered['cluster'] == selected_cluster]['clean_text'].tolist()

context = ' '.join(cluster_emails[:5])

context = context[:1024]

prompt = f"Based on the following emails:\n{context}\nA story about the interactions between employees in an office begins..."

from transformers import GPT2LMHeadModel, GPT2Tokenizer

model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

inputs = tokenizer(prompt, return_tensors='pt')

outputs = model.generate(
    inputs['input_ids'],
    attention_mask=inputs['attention_mask'],
    num_return_sequences=1,
    pad_token_id=tokenizer.eos_token_id,
    max_length=600,
    temperature=0.9,
    top_p=0.9,
    repetition_penalty=1.2
)

generated_story = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(generated_story)
# Out:
# Based on the following emails:
# , -- -- -- -- -- -- -- -- -- -- -- Forwarded Phillip K Allen/HOU/ECT 10/16/2000, 01:42 PM -- -- -- -- -- -- -- -- -- -- -- -- -- -,,, Buckner, Buck < buck.buckner @ honeywell.com > 10/12/2000 01:12:21 PM, : \Pallen @ Enron.com\ < Pallen @ Enron.com >, cc :, Subject : FW : fixed forward Collar floor gas price terms,,, Phillip,,, > discussed phone conversation, Parallon 75 microturbine, > power generation deal national accounts customer, developing, > proposal sell power customer fixed collar/floor price., > need corresponding term gas price. Microturbine, > onsite generation product developed Honeywell generate electricity, > customer site ( degen ). using natural gas., need, > best fixed price forward gas price deal 1, 3, 5, 7 10 years, > annual/seasonal supply microturbines generate fixed kWh, > customer. opportunity sell customer kWh using, > microturbine sell turbines. kWh deal must limited/, > risk forward gas price make deal work. Therein comes Sempra energy, > gas t
# A story about the interactions between employees in an office begins... The first thing that happens is a lot of people start to talk and then they get very angry at each other for not doing something right or wrong with their colleagues' lives... I think it's important we all understand what this means when you're working together as one company because if there are things going well but your boss doesn't do them properly he can be fired from his job immediately after having done some bad stuff.... It makes sense why so many companies have these problems.... If someone has been involved before getting hired by another person who was also part owner etc., how does anyone know where those relationships ended? And even though most managers don`T want any kind'relationship', sometimes just being around others will help keep everyone happy.. So let me ask my question.. What would happen without management? How could such situations occur?? Would our team members feel like "I am here" while still managing us?? Is every employee really responsible??? We should always take care of ourselves! But maybe no matter which way somebody goes out into business..... Maybe nobody ever gets paid enough money!!
